# %% [markdown]
# # # Breast Cancer Survival Analysis from Harberman Dataset

# %% [markdown]
# Obejective :
#         Analysis Given Dataset conducted between 1958 and 1970 on survival of patient who had undergone surgery for breast Cancer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv('E:/My AI/haberman.csv',names=['age','operation_year','axillary_node','survival_status_5y'])

# %%
data.columns
# Out:
# Index(['age', 'operation_year', 'axillary_node', 'survival_status_5y'], dtype='object')

# %% [markdown]
# ### 2D Plots ####

# %% [markdown]
# Scatter Plot

# %%
data.plot(kind='scatter',x='age',y='axillary_node')
plt.show()
print(np.mean(data['axillary_node']))
print(np.median(data['axillary_node']))
print(np.std(data['axillary_node']))
# Out:
# 4.026143790849673
# 1.0
# 7.177896092811152

# %% [markdown]
# Observation :
# * From First set of analysis using Scatter plot we observer that our majarity of the axillary nodes <25
# * We observer majaroity of the patients are not having axillary nodes across ages

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data,hue="survival_status_5y",size=4).map(plt.scatter,"age","axillary_node")
plt.legend()
plt.show()

# %% [markdown]
# observation:
# * Survival status (class attribute) 1 = the patient survived 5 years or longer 2 = the patient died within 5 year
# * We observe here that patients less than age 40 are less prone to death

# %%
sns.set_style("whitegrid")
sns.pairplot(data,hue="survival_status_5y",size=3)

# %% [markdown]
# # UniVarient

# %%
print(list(data['survival_status_5y'].unique()))
Alive=data.loc[data['survival_status_5y'] ==1];
Dead=data.loc[data['survival_status_5y']==2];
plt.plot(Alive['age'],np.zeros_like(Alive['age']))
plt.plot(Alive['operation_year'],np.zeros_like(Alive['operation_year']))
plt.plot(Alive['axillary_node'],np.zeros_like(Alive['axillary_node']))
plt.show()
# Out:
# [1, 2]

# %%
import warnings
warnings.filterwarnings("ignore") 
sns.FacetGrid(data,hue="survival_status_5y",size=6).map(sns.distplot,"axillary_node")
data.describe()
# Out:
#               age  operation_year  axillary_node  survival_status_5y
# count  306.000000      306.000000     306.000000          306.000000
# mean    52.457516       62.852941       4.026144            1.264706
# std     10.803452        3.249405       7.189654            0.441899
# min     30.000000       58.000000       0.000000            1.000000
# 25%     44.000000       60.000000       0.000000            1.000000
# 50%     52.000000       63.000000       1.000000            1.000000
# 75%     60.750000       65.750000       4.000000            2.000000
# max     83.000000       69.000000      52.000000            2.000000

# %% [markdown]
# Obseration:
# -We Found auxillary Node > 5 more prone to death
# -we Found patients having 0 axillary nodes have 2.5 times higher chance to be alive

# %%
counts, bin_edges=np.histogram(Alive['axillary_node'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf)
print(bin_edges)
#CDF
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1: ],pdf)
plt.plot(bin_edges[1: ],cdf)
#Dead
counts, bin_edges=np.histogram(Dead['axillary_node'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf)
print(bin_edges)
#CDF
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1: ],pdf)
plt.plot(bin_edges[1: ],cdf)
plt.show
# Out:
# [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]
# [0.56790123 0.14814815 0.13580247 0.04938272 0.07407407 0.
#  0.01234568 0.         0.         0.01234568]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# If axillary_node>45 more probablity of death is high
# CDF intersecting point is 25

# %%
sns.boxplot(x='survival_status_5y',y='axillary_node',data=data)
plt.show()

# %% [markdown]
# Observation:
# 60% of error may happen
# Paitents with axillary_node<5 has more surivival possibilities

# %%
sns.violinplot(x='survival_status_5y',y='axillary_node',data=data,size=8)
plt.show()
